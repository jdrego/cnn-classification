# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt
import numpy as np
import os
import time
import random
import collections
try:
    from apex import amp, optimizers
    from apex.parallel import DistributedDataParallel as DDP
    from apex.fp16_utils import *
except ImportError:
    raise ImportError("Apex not installed")

# %%
net_model = 'LeNet'
augment_dataset = True
if augment_dataset:
    CHECKPOINT_DIR = './checkpoints/' + net_model + '/'
else:
    CHECKPOINT_DIR = './checkpoints/' + net_model + '/'


# Number of gpus
n_gpu = 2
# Use Nvidia Apex for Auto Mixed Precision (AMP) on Tensorcores
use_amp = False
# Mixed-precision Operation Level
opt_level = 'O1'

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('device:', device)
# Out:
# device: cuda:0

# %%
def AddGaussNoise(x):
    #prob_noise = random.random()
    #if prob_noise >= 0.75:
        ## add random noise to the input images
        x = x + 0.05 * torch.randn(*x.shape)
        # Clip the images to be between 0 and 1
        x = np.clip(x, 0., 1.)
        return x

# %%
# number of subprocesses to use for data loading
num_workers = 2
# how many samples per batch to load
batch_size = 128
# percentage of training set to use as validation
valid_size = 0.2

transform = transforms.Compose([transforms.ToTensor(),
                                     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
transform_augm = transforms.Compose([transforms.RandomHorizontalFlip(), # randomly flip and rotate
                                      #transforms.RandomVerticalFlip(),
                                      transforms.RandomAffine(degrees=10,translate=(.05,.05)),
                                      #transforms.RandomRotation(10),
                                      transforms.CenterCrop((26,26)),
                                      transforms.Pad(padding=(3,3,3,3), padding_mode='symmetric'),
                                      transforms.ToTensor(),
                                      transforms.RandomApply([transforms.Lambda(AddGaussNoise)],p=0.25),
                                      #AddGaussianNoise(0.05,0.05),
                                      #transforms.RandomApply([AddGaussianNoise(0.05,0.05)], p=0.5),
                                      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
#####################
## Import Datasets ##
#####################
# Import Datasets
trainset = datasets.CIFAR10(root='./data', train=True,
                            download=True, transform=transform)
validset = datasets.CIFAR10(root='./data', train=True,
                            download=True, transform=transform)
testset = datasets.CIFAR10(root='./data', train=False,
                            download=True, transform=transform)

# obtain training indices that will be used for validation
num_train = len(trainset)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

trainloader = DataLoader(trainset, batch_size=batch_size,
                         sampler=train_sampler, num_workers=num_workers)
validloader = DataLoader(validset, batch_size=batch_size,
                         sampler=valid_sampler, num_workers=num_workers)
testloader = DataLoader(testset, batch_size=batch_size,
                        shuffle=True, num_workers=num_workers)

# Define Classes
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Display some training images
def imshow(img):
    img = img / 2 + 0.5     #unnormalize
    npimg = img.numpy()
    plt.figure(figsize=(20,10))
    plt.imshow(np.transpose(npimg, (1,2,0)))
    plt.show()

# Get some training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# Show images
imshow(torchvision.utils.make_grid(images[:5]))
# Print labels
print(' \t\t\t '.join('%5s' % classes[labels[j]] for j in range(5)))
# Out:
# truck 			  bird 			  frog 			 plane 			  deer

# %%
#############################
## Define CNN Architecture ##
#############################
class LeNet(nn.Module):
    def __init__(self):
        super(LeNet, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x
print('NETWORK MODEL:'); print(LeNet()); print()
# Out:
# NETWORK MODEL:
# LeNet(
#   (conv1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %%
def model_init(load_type='train', checkpoint_type='validate', checkpoint=-1):
    learning_rate = 0.003
    sched_gamma = 0.9
    sched_step = 10
    
    # Initialize model
    model = LeNet()
    # Send model to GPU
    model = model.to(device)
    
    if load_type=='train' or load_type=='restart':
        # Initialize Loss Function    
        criterion = nn.CrossEntropyLoss()
        # Initialize SGD Optimizer
        optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)
        # Initialize Learning Rate Scheduler
        scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=sched_step, gamma=sched_gamma, last_epoch=-1)
        
        # Amp Initialization
        if use_amp:
            model, optimizer = amp.initialize(model, optimizer, opt_level=opt_level)

    # Split model between GPUs
    if n_gpu > 1:
        model = nn.DataParallel(model, list(range(n_gpu)))

    ##############################
    ## LOAD PREVIOUS CHECKPOINT ##
    ##############################
    # Define directory to save and load checkpoints
    LOAD_DIR = CHECKPOINT_DIR + checkpoint_type + '/'
    print('Loading checkpoints from directory:', LOAD_DIR)
    if load_type == 'restart':
        checkpoints = []
    else:
        # Read in available checkpoints and sort 
        checkpoints = sorted([f for f in os.listdir(LOAD_DIR) if os.path.isfile(LOAD_DIR + f)])
        print(); print('CHECKPOINTS AVAILABLE:'); print(checkpoints)
    
    # If no checkpoints available
    if len(checkpoints) == 0:
        print('Last Checkpoint: [None]')
        # Start from first epoch
        last_epoch = 0
        loss_min = np.Inf
    # Else if checkpoints available
    else:
        # Load latest checkpoint
        if checkpoint == -1:
            load_checkpoint = checkpoints[-1]
        # Load specified checkpoint
        else:
            load_checkpoint = 'cifar_net_' + checkpoint + '.pt'
        print('Loading Checkpoint:', load_checkpoint)
        
        # Use checkpoint number as last epoch
        last_epoch = int(load_checkpoint[12:-3])
        # Load latest checkpoint
        latest_checkpoint = torch.load(LOAD_DIR + load_checkpoint)

        # Load model state to resume training
        model.load_state_dict(latest_checkpoint['net'])
        
        if load_type=='train':
            model.train()
            # Load Optimizer, Scheduler, and Amp State
            optimizer.load_state_dict(latest_checkpoint['optimizer'])
            scheduler.load_state_dict(latest_checkpoint['scheduler'])
            if use_amp:
                amp.load_state_dict(latest_checkpoint['amp'])
           
            loss_min = latest_checkpoint['loss']
            
                

            # Reassign Scheduler gamma if desired.
            scheduler.gamma = sched_gamma
            scheduler.step_size = sched_step
        else:
            model.eval()
    
    print('Last Epoch:', last_epoch); print()
    print('MODEL STATE_DICT:')
    for param_tensor in model.state_dict():
        print(param_tensor, "\t", model.state_dict()[param_tensor].size())
    print()
    if load_type=='train' or load_type=='restart':
        print('OPTIMIZER STATE_DICT:')
        for var_name in optimizer.state_dict():
            if var_name != 'state':
                print(var_name, "\t", optimizer.state_dict()[var_name])
        print(); print('SCHEDULER STATE_DICT:')
        for var_name in scheduler.state_dict():
            print(var_name, "\t", scheduler.state_dict()[var_name])
        print('Learning Rate:', scheduler.get_lr()); print()
        
        return model, criterion, optimizer, scheduler, last_epoch, loss_min
    else:
        return model

# %%
model, criterion, optimizer, scheduler, last_epoch, loss_min = model_init(load_type='train', checkpoint_type='validate')
optimizer.param_groups[0]['lr'] = 0.001
#######################
## Train the Network ##
#######################

# Define Number of Epochs to train
n_epochs = 100
if scheduler.last_epoch == 0:
    valid_loss_min = np.Inf # track change in validation loss
else:
    valid_loss_min = loss_min

for epoch in range(last_epoch, last_epoch+n_epochs):
    #print('EPOCH:', epoch+1, '\t LR:', scheduler.get_lr())
    # Save start times
    ep_start = time.time()
    
    # keep track of training and validation loss
    train_loss = 0.0
    valid_loss = 0.0
    running_loss = 0.0
    ######################    
    # Train the model #
    ######################
    # For each batch
    for i, data in enumerate(trainloader, 0):
        iter_start = time.time()
        # get the inputs; data is a list of [inputs, labels]
        #inputs, labels = data[0].to(device), data[1].to(device)
        inputs, labels = data[0], data[1]
        
        # Zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = model(inputs.to(device))
        loss = criterion(outputs, labels.to(device))
        
        if use_amp:
            with amp.scale_loss(loss, optimizer) as scaled_loss:
                scaled_loss.backward()
        else:
            loss.backward()
        optimizer.step()
        
        # Print Statistics
        train_loss += loss.item()*inputs.size(0)
        running_loss += loss.item()
        if i % 100 == 99:
            iter_time = time.time() - iter_start
            #print('[%d, %5d] loss: %.3f, TIME: %.3f seconds' %
            #      (epoch + 1, i + 1, running_loss / 100, iter_time))
            running_loss = 0.0
    ######################    
    # validate the model #
    ######################
    model.eval()
    for i, data in enumerate(validloader):
        # move tensors to GPU if CUDA is available
        inputs, labels = data[0].to(device), data[1].to(device)
        # forward pass: compute predicted outputs by passing inputs to the model
        outputs = model(inputs)
        # calculate the batch loss
        loss = criterion(outputs, labels)
        # update average validation loss 
        valid_loss += loss.item()*inputs.size(0)
    
    # Mark epoch time
    ep_time = time.time() - ep_start
    
    # calculate average epoch losses
    train_loss = train_loss/len(trainloader.sampler)
    valid_loss = valid_loss/len(validloader.sampler)

    # print training/validation statistics 
    print('Epoch: {} \t Learning Rate: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f} \tTIME: {:.3f}'.format(
        epoch+1, scheduler.get_lr(), train_loss, valid_loss, ep_time))
    # Step Learning Rate Scheduler
    scheduler.step()
    
    #print('END EPOCH:', epoch+1, 'TIME:', ep_time, 'seconds'); print()
    
    # Save checkpoint every 5 epochs
    if use_amp:
            amp_state = amp.state_dict()
    else:
            amp_state = None        
    if (epoch+1) % 5 == 0:
        PATH = CHECKPOINT_DIR+'train/train_LeNet_' + str(epoch+1) + '.pt'
        current_state = {'net': model.state_dict(),
                         'optimizer': optimizer.state_dict(),
                         'scheduler': scheduler.state_dict(),
                         'amp': amp_state,
                         'loss': valid_loss}
        torch.save(current_state, PATH)
        print('Checkpoint for Epoch', epoch+1, 'saved in', PATH)
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        VALID_PATH = CHECKPOINT_DIR+'validate/valid_LeNet_' + str(epoch+1) + '.pt'
        current_state = {'net': model.state_dict(),
                         'optimizer': optimizer.state_dict(),
                         'scheduler': scheduler.state_dict(),
                         'amp': amp_state,
                         'loss': valid_loss}
        torch.save(current_state, VALID_PATH)
        valid_loss_min = valid_loss
print('Finished Training')
# Out:
# Loading checkpoints from directory: ./checkpoints/LeNet/validate/
#
# CHECKPOINTS AVAILABLE:
# ['valid_LeNet_100.pt', 'valid_LeNet_101.pt', 'valid_LeNet_102.pt']
# Loading Checkpoint: valid_LeNet_102.pt
# Last Epoch: 102
#
# MODEL STATE_DICT:
# module.conv1.weight 	 torch.Size([6, 3, 5, 5])
# module.conv1.bias 	 torch.Size([6])
# module.conv2.weight 	 torch.Size([16, 6, 5, 5])
# module.conv2.bias 	 torch.Size([16])
# module.fc1.weight 	 torch.Size([120, 400])
# module.fc1.bias 	 torch.Size([120])
# module.fc2.weight 	 torch.Size([84, 120])
# module.fc2.bias 	 torch.Size([84])
# module.fc3.weight 	 torch.Size([10, 84])
# module.fc3.bias 	 torch.Size([10])
#
# OPTIMIZER STATE_DICT:
# param_groups 	 [{'lr': 3.875953108451434e-05, 'momentum': 0.9, 'dampening': 0, 'weight_decay': 0, 'nesterov': False, 'initial_lr': 0.001, 'params': [140632129307664, 140632129307744, 140632129307584, 140632129307824, 140632129307904, 140632129307984, 140632129308064, 140632129308144, 140632129308224, 140632129308304]}]
#
# SCHEDULER STATE_DICT:
# step_size 	 10
# gamma 	 0.9
# base_lrs 	 [0.001]
# last_epoch 	 102
# Learning Rate: [3.875953108451434e-05]
#
# Epoch: 103 	 Learning Rate: [0.001] 	Training Loss: 1.177902 	Validation Loss: 1.220905 	TIME: 3.727
# Epoch: 104 	 Learning Rate: [0.001] 	Training Loss: 1.154275 	Validation Loss: 1.217309 	TIME: 3.734
# Epoch: 105 	 Learning Rate: [0.001] 	Training Loss: 1.145687 	Validation Loss: 1.219585 	TIME: 3.740
# Checkpoint for Epoch 105 saved in ./checkpoints/LeNet/train/train_LeNet_105.pt
# Epoch: 106 	 Learning Rate: [0.001] 	Training Loss: 1.126901 	Validation Loss: 1.189500 	TIME: 3.811
# Validation loss decreased (1.194870 --> 1.189500).  Saving model ...
# Epoch: 107 	 Learning Rate: [0.001] 	Training Loss: 1.110765 	Validation Loss: 1.189264 	TIME: 3.656
# Validation loss decreased (1.189500 --> 1.189264).  Saving model ...
# Epoch: 108 	 Learning Rate: [0.001] 	Training Loss: 1.103571 	Validation Loss: 1.191801 	TIME: 3.698
# Epoch: 109 	 Learning Rate: [0.001] 	Training Loss: 1.094555 	Validation Loss: 1.165820 	TIME: 3.751
# Validation loss decreased (1.189264 --> 1.165820).  Saving model ...
# Epoch: 110 	 Learning Rate: [0.001] 	Training Loss: 1.077594 	Validation Loss: 1.174768 	TIME: 3.732
# Checkpoint for Epoch 110 saved in ./checkpoints/LeNet/train/train_LeNet_110.pt
# Epoch: 111 	 Learning Rate: [0.0008100000000000001] 	Training Loss: 1.066228 	Validation Loss: 1.151075 	TIME: 3.670
# Validation loss decreased (1.165820 --> 1.151075).  Saving model ...
# Epoch: 112 	 Learning Rate: [0.0009000000000000001] 	Training Loss: 1.048496 	Validation Loss: 1.151146 	TIME: 3.758
# Epoch: 113 	 Learning Rate: [0.0009000000000000001] 	Training Loss: 1.043916 	Validation Loss: 1.151263 	TIME: 3.756
# Epoch: 114 	 Learning Rate: [0.0009000000000000001] 	Training Loss: 1.034250 	Validation Loss: 1.153062 	TIME: 3.747
# Epoch: 115 	 Learning Rate: [0.0009000000000000001] 	Training Loss: 1.025543 	Validation Loss: 1.141875 	TIME: 3.698
# Checkpoint for Epoch 115 saved in ./checkpoints/LeNet/train/train_LeNet_115.pt
# Validation loss decreased (1.151075 --> 1.141875).  Saving model ...
# Epoch: 116 	 Learning Rate: [0.0009000000000000001] 	Training Loss: 1.017545 	Validation Loss: 1.126819 	TIME: 3.729
# Validation loss decreased (1.141875 --> 1.126819).  Saving model ...
# Epoch: 117 	 Learning Rate: [0.0009000000000000001] 	Training Loss: 1.008855 	Validation Loss: 1.118785 	TIME: 3.754
# Validation loss decreased (1.126819 --> 1.118785).  Saving model ...
# Epoch: 118 	 Learning Rate: [0.0009000000000000001] 	Training Loss: 0.995868 	Validation Loss: 1.117278 	TIME: 3.754
# Validation loss decreased (1.118785 --> 1.117278).  Saving model ...
# Epoch: 119 	 Learning Rate: [0.0009000000000000001] 	Training Loss: 0.990902 	Validation Loss: 1.103577 	TIME: 3.707
# Validation loss decreased (1.117278 --> 1.103577).  Saving model ...
# Epoch: 120 	 Learning Rate: [0.0009000000000000001] 	Training Loss: 0.984177 	Validation Loss: 1.136059 	TIME: 3.773
# Checkpoint for Epoch 120 saved in ./checkpoints/LeNet/train/train_LeNet_120.pt
# Epoch: 121 	 Learning Rate: [0.000729] 	Training Loss: 0.972157 	Validation Loss: 1.130923 	TIME: 3.723
# Epoch: 122 	 Learning Rate: [0.0008100000000000001] 	Training Loss: 0.963885 	Validation Loss: 1.094136 	TIME: 3.707
# Validation loss decreased (1.103577 --> 1.094136).  Saving model ...
# Epoch: 123 	 Learning Rate: [0.0008100000000000001] 	Training Loss: 0.953138 	Validation Loss: 1.101055 	TIME: 3.786
# Epoch: 124 	 Learning Rate: [0.0008100000000000001] 	Training Loss: 0.944758 	Validation Loss: 1.096981 	TIME: 3.717
# Epoch: 125 	 Learning Rate: [0.0008100000000000001] 	Training Loss: 0.941531 	Validation Loss: 1.086320 	TIME: 3.688
# Checkpoint for Epoch 125 saved in ./checkpoints/LeNet/train/train_LeNet_125.pt
# Validation loss decreased (1.094136 --> 1.086320).  Saving model ...
# Epoch: 126 	 Learning Rate: [0.0008100000000000001] 	Training Loss: 0.930890 	Validation Loss: 1.086988 	TIME: 3.704
# Epoch: 127 	 Learning Rate: [0.0008100000000000001] 	Training Loss: 0.924668 	Validation Loss: 1.086289 	TIME: 3.732
# Validation loss decreased (1.086320 --> 1.086289).  Saving model ...
# Epoch: 128 	 Learning Rate: [0.0008100000000000001] 	Training Loss: 0.920610 	Validation Loss: 1.076095 	TIME: 3.712
# Validation loss decreased (1.086289 --> 1.076095).  Saving model ...
# Epoch: 129 	 Learning Rate: [0.0008100000000000001] 	Training Loss: 0.913364 	Validation Loss: 1.089822 	TIME: 3.734
# Epoch: 130 	 Learning Rate: [0.0008100000000000001] 	Training Loss: 0.909954 	Validation Loss: 1.114234 	TIME: 3.726
# Checkpoint for Epoch 130 saved in ./checkpoints/LeNet/train/train_LeNet_130.pt
# Epoch: 131 	 Learning Rate: [0.0006561000000000001] 	Training Loss: 0.893784 	Validation Loss: 1.085905 	TIME: 3.694
# Epoch: 132 	 Learning Rate: [0.000729] 	Training Loss: 0.885286 	Validation Loss: 1.078406 	TIME: 3.720
# Epoch: 133 	 Learning Rate: [0.000729] 	Training Loss: 0.882598 	Validation Loss: 1.100317 	TIME: 3.766
# Epoch: 134 	 Learning Rate: [0.000729] 	Training Loss: 0.875950 	Validation Loss: 1.074348 	TIME: 3.725
# Validation loss decreased (1.076095 --> 1.074348).  Saving model ...
# Epoch: 135 	 Learning Rate: [0.000729] 	Training Loss: 0.873991 	Validation Loss: 1.068312 	TIME: 3.703
# Checkpoint for Epoch 135 saved in ./checkpoints/LeNet/train/train_LeNet_135.pt
# Validation loss decreased (1.074348 --> 1.068312).  Saving model ...
# Epoch: 136 	 Learning Rate: [0.000729] 	Training Loss: 0.866733 	Validation Loss: 1.065493 	TIME: 3.677
# Validation loss decreased (1.068312 --> 1.065493).  Saving model ...
# Epoch: 137 	 Learning Rate: [0.000729] 	Training Loss: 0.856055 	Validation Loss: 1.076992 	TIME: 3.735
# Epoch: 138 	 Learning Rate: [0.000729] 	Training Loss: 0.856220 	Validation Loss: 1.084943 	TIME: 3.717
# Epoch: 139 	 Learning Rate: [0.000729] 	Training Loss: 0.846721 	Validation Loss: 1.071227 	TIME: 3.733
# Epoch: 140 	 Learning Rate: [0.000729] 	Training Loss: 0.845416 	Validation Loss: 1.091503 	TIME: 3.687
# Checkpoint for Epoch 140 saved in ./checkpoints/LeNet/train/train_LeNet_140.pt
# Epoch: 141 	 Learning Rate: [0.00059049] 	Training Loss: 0.832143 	Validation Loss: 1.072623 	TIME: 3.713
# Epoch: 142 	 Learning Rate: [0.0006561000000000001] 	Training Loss: 0.825504 	Validation Loss: 1.083162 	TIME: 3.715
# Epoch: 143 	 Learning Rate: [0.0006561000000000001] 	Training Loss: 0.820112 	Validation Loss: 1.089189 	TIME: 3.756
# Epoch: 144 	 Learning Rate: [0.0006561000000000001] 	Training Loss: 0.815468 	Validation Loss: 1.096076 	TIME: 3.767
# Epoch: 145 	 Learning Rate: [0.0006561000000000001] 	Training Loss: 0.812937 	Validation Loss: 1.091772 	TIME: 3.723
# Checkpoint for Epoch 145 saved in ./checkpoints/LeNet/train/train_LeNet_145.pt
# Epoch: 146 	 Learning Rate: [0.0006561000000000001] 	Training Loss: 0.804219 	Validation Loss: 1.077645 	TIME: 3.780
# Epoch: 147 	 Learning Rate: [0.0006561000000000001] 	Training Loss: 0.800994 	Validation Loss: 1.101892 	TIME: 3.806
# Epoch: 148 	 Learning Rate: [0.0006561000000000001] 	Training Loss: 0.797192 	Validation Loss: 1.093816 	TIME: 3.797
# Epoch: 149 	 Learning Rate: [0.0006561000000000001] 	Training Loss: 0.791474 	Validation Loss: 1.086179 	TIME: 3.791
# Epoch: 150 	 Learning Rate: [0.0006561000000000001] 	Training Loss: 0.789045 	Validation Loss: 1.085174 	TIME: 3.717
# Checkpoint for Epoch 150 saved in ./checkpoints/LeNet/train/train_LeNet_150.pt
# Epoch: 151 	 Learning Rate: [0.000531441] 	Training Loss: 0.778840 	Validation Loss: 1.076734 	TIME: 3.725
# Epoch: 152 	 Learning Rate: [0.00059049] 	Training Loss: 0.774348 	Validation Loss: 1.077180 	TIME: 3.749
# Epoch: 153 	 Learning Rate: [0.00059049] 	Training Loss: 0.767509 	Validation Loss: 1.099259 	TIME: 3.733
# Epoch: 154 	 Learning Rate: [0.00059049] 	Training Loss: 0.766259 	Validation Loss: 1.088363 	TIME: 3.708
# Epoch: 155 	 Learning Rate: [0.00059049] 	Training Loss: 0.759283 	Validation Loss: 1.077817 	TIME: 3.665
# Checkpoint for Epoch 155 saved in ./checkpoints/LeNet/train/train_LeNet_155.pt
# Epoch: 156 	 Learning Rate: [0.00059049] 	Training Loss: 0.754992 	Validation Loss: 1.095639 	TIME: 3.723
# Epoch: 157 	 Learning Rate: [0.00059049] 	Training Loss: 0.752168 	Validation Loss: 1.087185 	TIME: 3.685
# Epoch: 158 	 Learning Rate: [0.00059049] 	Training Loss: 0.746354 	Validation Loss: 1.117791 	TIME: 3.747
# Epoch: 159 	 Learning Rate: [0.00059049] 	Training Loss: 0.744752 	Validation Loss: 1.088902 	TIME: 3.767
# Epoch: 160 	 Learning Rate: [0.00059049] 	Training Loss: 0.734735 	Validation Loss: 1.098649 	TIME: 3.744
# Checkpoint for Epoch 160 saved in ./checkpoints/LeNet/train/train_LeNet_160.pt
# Epoch: 161 	 Learning Rate: [0.0004782969] 	Training Loss: 0.731278 	Validation Loss: 1.102869 	TIME: 3.787
# Epoch: 162 	 Learning Rate: [0.000531441] 	Training Loss: 0.725260 	Validation Loss: 1.099589 	TIME: 3.806
# Epoch: 163 	 Learning Rate: [0.000531441] 	Training Loss: 0.718453 	Validation Loss: 1.093642 	TIME: 3.687
# Epoch: 164 	 Learning Rate: [0.000531441] 	Training Loss: 0.718214 	Validation Loss: 1.096168 	TIME: 3.724
# Epoch: 165 	 Learning Rate: [0.000531441] 	Training Loss: 0.716174 	Validation Loss: 1.109357 	TIME: 3.798
# Checkpoint for Epoch 165 saved in ./checkpoints/LeNet/train/train_LeNet_165.pt
# Epoch: 166 	 Learning Rate: [0.000531441] 	Training Loss: 0.710619 	Validation Loss: 1.108338 	TIME: 3.753
# Epoch: 167 	 Learning Rate: [0.000531441] 	Training Loss: 0.706857 	Validation Loss: 1.135667 	TIME: 3.724
# Epoch: 168 	 Learning Rate: [0.000531441] 	Training Loss: 0.701150 	Validation Loss: 1.135118 	TIME: 3.735
# Epoch: 169 	 Learning Rate: [0.000531441] 	Training Loss: 0.701703 	Validation Loss: 1.116081 	TIME: 3.811
# Epoch: 170 	 Learning Rate: [0.000531441] 	Training Loss: 0.694381 	Validation Loss: 1.131286 	TIME: 3.771
# Checkpoint for Epoch 170 saved in ./checkpoints/LeNet/train/train_LeNet_170.pt
# Epoch: 171 	 Learning Rate: [0.00043046721] 	Training Loss: 0.687469 	Validation Loss: 1.124008 	TIME: 3.711
# Epoch: 172 	 Learning Rate: [0.0004782969] 	Training Loss: 0.687649 	Validation Loss: 1.125433 	TIME: 3.736
# Epoch: 173 	 Learning Rate: [0.0004782969] 	Training Loss: 0.681600 	Validation Loss: 1.125209 	TIME: 3.766
# Epoch: 174 	 Learning Rate: [0.0004782969] 	Training Loss: 0.675597 	Validation Loss: 1.131836 	TIME: 3.712
# Epoch: 175 	 Learning Rate: [0.0004782969] 	Training Loss: 0.672586 	Validation Loss: 1.135627 	TIME: 3.770
# Checkpoint for Epoch 175 saved in ./checkpoints/LeNet/train/train_LeNet_175.pt
# Epoch: 176 	 Learning Rate: [0.0004782969] 	Training Loss: 0.673146 	Validation Loss: 1.128969 	TIME: 3.728
# Epoch: 177 	 Learning Rate: [0.0004782969] 	Training Loss: 0.666815 	Validation Loss: 1.146719 	TIME: 3.774
# Epoch: 178 	 Learning Rate: [0.0004782969] 	Training Loss: 0.664634 	Validation Loss: 1.129361 	TIME: 3.664
# Epoch: 179 	 Learning Rate: [0.0004782969] 	Training Loss: 0.662194 	Validation Loss: 1.139894 	TIME: 3.759
# Epoch: 180 	 Learning Rate: [0.0004782969] 	Training Loss: 0.658303 	Validation Loss: 1.151479 	TIME: 3.698
# Checkpoint for Epoch 180 saved in ./checkpoints/LeNet/train/train_LeNet_180.pt
# Epoch: 181 	 Learning Rate: [0.000387420489] 	Training Loss: 0.648866 	Validation Loss: 1.161786 	TIME: 3.762
# Epoch: 182 	 Learning Rate: [0.00043046721] 	Training Loss: 0.646704 	Validation Loss: 1.148104 	TIME: 3.747
# Epoch: 183 	 Learning Rate: [0.00043046721] 	Training Loss: 0.645435 	Validation Loss: 1.141196 	TIME: 3.836
# Epoch: 184 	 Learning Rate: [0.00043046721] 	Training Loss: 0.641427 	Validation Loss: 1.149472 	TIME: 3.751
# Epoch: 185 	 Learning Rate: [0.00043046721] 	Training Loss: 0.638018 	Validation Loss: 1.146820 	TIME: 3.699
# Checkpoint for Epoch 185 saved in ./checkpoints/LeNet/train/train_LeNet_185.pt
# Epoch: 186 	 Learning Rate: [0.00043046721] 	Training Loss: 0.638019 	Validation Loss: 1.180786 	TIME: 3.776
# Epoch: 187 	 Learning Rate: [0.00043046721] 	Training Loss: 0.632130 	Validation Loss: 1.163806 	TIME: 3.688
# Epoch: 188 	 Learning Rate: [0.00043046721] 	Training Loss: 0.627141 	Validation Loss: 1.158736 	TIME: 3.686
# Epoch: 189 	 Learning Rate: [0.00043046721] 	Training Loss: 0.626914 	Validation Loss: 1.155154 	TIME: 3.748
# Epoch: 190 	 Learning Rate: [0.00043046721] 	Training Loss: 0.623860 	Validation Loss: 1.174075 	TIME: 3.819
# Checkpoint for Epoch 190 saved in ./checkpoints/LeNet/train/train_LeNet_190.pt
# Epoch: 191 	 Learning Rate: [0.0003486784401] 	Training Loss: 0.615566 	Validation Loss: 1.170739 	TIME: 3.766
# Epoch: 192 	 Learning Rate: [0.000387420489] 	Training Loss: 0.615678 	Validation Loss: 1.169362 	TIME: 3.734
# Epoch: 193 	 Learning Rate: [0.000387420489] 	Training Loss: 0.610331 	Validation Loss: 1.180090 	TIME: 3.747
# Epoch: 194 	 Learning Rate: [0.000387420489] 	Training Loss: 0.609531 	Validation Loss: 1.206471 	TIME: 3.675
# Epoch: 195 	 Learning Rate: [0.000387420489] 	Training Loss: 0.606296 	Validation Loss: 1.206755 	TIME: 3.815
# Checkpoint for Epoch 195 saved in ./checkpoints/LeNet/train/train_LeNet_195.pt
# Epoch: 196 	 Learning Rate: [0.000387420489] 	Training Loss: 0.604533 	Validation Loss: 1.177286 	TIME: 3.695
# Epoch: 197 	 Learning Rate: [0.000387420489] 	Training Loss: 0.602308 	Validation Loss: 1.198126 	TIME: 3.826
# Epoch: 198 	 Learning Rate: [0.000387420489] 	Training Loss: 0.597924 	Validation Loss: 1.191886 	TIME: 3.713
# Epoch: 199 	 Learning Rate: [0.000387420489] 	Training Loss: 0.593728 	Validation Loss: 1.201784 	TIME: 3.764
# Epoch: 200 	 Learning Rate: [0.000387420489] 	Training Loss: 0.595349 	Validation Loss: 1.214793 	TIME: 3.727
# Checkpoint for Epoch 200 saved in ./checkpoints/LeNet/train/train_LeNet_200.pt
# Epoch: 201 	 Learning Rate: [0.00031381059609000004] 	Training Loss: 0.585137 	Validation Loss: 1.216971 	TIME: 3.779
# Epoch: 202 	 Learning Rate: [0.0003486784401] 	Training Loss: 0.582796 	Validation Loss: 1.216663 	TIME: 3.686
# Finished Training

# %%
model = model_init(load_type='validate', checkpoint_type='validate', checkpoint=-1)
model.eval()
dataiter = iter(testloader)
images, labels = dataiter.next()

# Print Images
imshow(torchvision.utils.make_grid(images[:5]))
print('GroundTruth:', ' '.join('%5s \t ' % classes[labels[j]] for j in range(5)))


"""
model = LeNet()
model.to(device)
if n_gpu > 1:
    model = nn.DataParallel(model, list(range(n_gpu)))

# Load latest checkpoint
latest_checkpoint = torch.load(PATH)
    
# Load model state
model.load_state_dict(latest_checkpoint['net'])
model.eval()
"""

images, labels = images.to(device), labels.to(device)
outputs = model(images)

_, predicted = torch.max(outputs[:5], 1)
print('Predicted: ', ' '.join('%5s \t ' % classes[predicted[j]] for j in range(5)))
# Out:
# Loading checkpoints from directory: ./checkpoints/LeNet/validate/
#
# CHECKPOINTS AVAILABLE:
# ['valid_LeNet_100.pt', 'valid_LeNet_101.pt', 'valid_LeNet_102.pt', 'valid_LeNet_106.pt', 'valid_LeNet_107.pt', 'valid_LeNet_109.pt', 'valid_LeNet_111.pt', 'valid_LeNet_115.pt', 'valid_LeNet_116.pt', 'valid_LeNet_117.pt', 'valid_LeNet_118.pt', 'valid_LeNet_119.pt', 'valid_LeNet_122.pt', 'valid_LeNet_125.pt', 'valid_LeNet_127.pt', 'valid_LeNet_128.pt', 'valid_LeNet_134.pt', 'valid_LeNet_135.pt', 'valid_LeNet_136.pt']
# Loading Checkpoint: valid_LeNet_136.pt
# Last Epoch: 136
#
# MODEL STATE_DICT:
# module.conv1.weight 	 torch.Size([6, 3, 5, 5])
# module.conv1.bias 	 torch.Size([6])
# module.conv2.weight 	 torch.Size([16, 6, 5, 5])
# module.conv2.bias 	 torch.Size([16])
# module.fc1.weight 	 torch.Size([120, 400])
# module.fc1.bias 	 torch.Size([120])
# module.fc2.weight 	 torch.Size([84, 120])
# module.fc2.bias 	 torch.Size([84])
# module.fc3.weight 	 torch.Size([10, 84])
# module.fc3.bias 	 torch.Size([10])
# GroundTruth:   cat 	    car 	   ship 	    car 	    car
# Predicted:    cat 	    car 	   ship 	    car 	    car

# %%
correct = 0
total = 0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total)); print()
for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of the network on the 10000 test images: 63 %
#
# Accuracy of plane : 76 %
# Accuracy of   car : 68 %
# Accuracy of  bird : 56 %
# Accuracy of   cat : 42 %
# Accuracy of  deer : 60 %
# Accuracy of   dog : 51 %
# Accuracy of  frog : 64 %
# Accuracy of horse : 81 %
# Accuracy of  ship : 69 %
# Accuracy of truck : 54 %
